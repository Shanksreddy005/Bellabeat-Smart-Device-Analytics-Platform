# %% [markdown]
# # Phase 4: Analyze (Statistical Reasoning & Segmentation)
# This notebook runs the statistical tests (paired t-tests and Wilcoxon tests) and evaluates KMeans clustering against business-rule segmentation.

# %%
import sys
sys.path.append('../scripts')
import analysis
import pandas as pd

df = pd.read_csv('../data/processed/engineered_features.csv')

# Run hypothesis tests
tests_text = analysis.run_hypothesis_tests(df)
print(tests_text)

# %% [markdown]
# ### KMeans Clustering Comparison

# %%
cluster_text = analysis.run_clustering_analysis(df)
print(cluster_text)
