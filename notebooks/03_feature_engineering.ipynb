# %% [markdown]
# # Phase 3: Process (Feature Engineering)
# This notebook runs the feature engineering script to add behavioral flags, wear compliance metrics, sleep efficiency, and user activity segments.

# %%
import sys
sys.path.append('../scripts')
import feature_engineering

# Run feature engineering pipeline
feat_df = feature_engineering.engineer_features()
print("Engineered features dimensions:", feat_df.shape)

# %% [markdown]
# ### Sample Engineered Features

# %%
feat_df[['Id', 'ActivityDate', 'sleep_efficiency', 'sedentary_ratio', 'user_activity_segment', 'highly_active_day_flag', 'weekend_activity_change']].head()
